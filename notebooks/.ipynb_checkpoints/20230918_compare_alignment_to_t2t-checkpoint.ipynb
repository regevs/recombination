# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as mtick

import matplotlib.lines
from pathlib import Path
import fastq as fq
import tqdm
import re
import sys
import seaborn as sns
import scipy.stats
import os
import msprime
import pysam

# This is needed before pybedtools to make sure bedtools is imported on sanger JupyterHub 
os.environ["PATH"] += ":" + os.path.join(sys.prefix, "bin")
import pybedtools

# %%
sys.path.append("/nfs/users/nfs_r/rs42/rs42/git/hapfusion/src")
sys.path.append("/nfs/users/nfs_r/rs42/rs42/git/himut/src")

sys.path.append(str(Path(os.getcwd()).parent))
from src import liftover, annotate

# %%
import hapfusion
import himut

# %% [markdown]
# # Which samples?

# %%
aut_chrom_names = [f"chr{i}" for i in list(range(1, 23))]
chrom_names = aut_chrom_names + ["chrX", "chrY"]

# %%
sample_ids = [
    "PD50477f",
    # "PD50508bf", -- ignore; merged two sampling dates just for phasing, but should be analyzed separately
    "PD50519d",
    # "PD47269d", -- don't use, not there
    "PD50508f",
    # "PD50511e", -- don't use, likely mixture
    "PD50523b",
    # "PD48473b", -- don't use, not there
    "PD50521b",
    "PD50508b",
    # "PD50521be", -- ignore; merged two sampling dates just for phasing, but should be analyzed separately
    "PD46180c",
    # "PD50502f", -- don't use, likely mixture
    "PD50521e",
    # "PD50511e_SS",  --- don't use
    "PD50489e",
]

# %% [markdown]
# # Functions to load _hapfusion_ summary files

# %% [markdown]
# ## Loading files using T2T as reference

# %%
t2t_hapfusion_output_path = Path("/lustre/scratch126/casm/team154pc/sl17/03.sperm/02.results/01.read_alignment/01.ccs/03.T2T-CHM13")

def t2t_load_files(sample_id):
    data_path = t2t_hapfusion_output_path / sample_id

    reads_df = pd.read_csv(
        str(data_path / f"chm13.{sample_id}.hapfusion.txt"),
        comment="#",
        delim_whitespace=True,
        header=None,
    )

    log_df = pd.read_csv(
        str(data_path / "hapfusion.log"),
        delim_whitespace=True,
        index_col=0,
    )

    candidates_df = pd.read_csv(
        str(data_path / "hapfusion_candidates.txt"),
        delim_whitespace=True,
    )

    return {"reads": reads_df, "summary": log_df, "candidates": candidates_df}

# %% [markdown]
# ## Loading files using hg19 as reference

# %%
hg19_hapfusion_output_path = Path("/lustre/scratch126/casm/team154pc/sl17/03.sperm/02.results/01.read_alignment/01.ccs/01.grch37")

def hg19_load_files(sample_id):
    data_path = hg19_hapfusion_output_path / sample_id

    reads_df = pd.read_csv(
        str(data_path / f"hg19.{sample_id}.hapfusion.txt"),
        comment="#",
        delim_whitespace=True,
        header=None,
    )

    log_df = pd.read_csv(
        str(data_path / "hapfusion.log"),
        delim_whitespace=True,
        index_col=0,
    )

    candidates_df = pd.read_csv(
        str(data_path / "hapfusion_candidates.txt"),
        delim_whitespace=True,
    )

    return {"reads": reads_df, "summary": log_df, "candidates": candidates_df}

# %% [markdown]
# ## Loading files using de-novo assembly as reference

# %%
denovo_hapfusion_output_path = Path("/lustre/scratch126/casm/team154pc/sl17/03.sperm/02.results/01.read_alignment/01.ccs/04.hifiasm/02.hifiasm_0.19.5-r592/02.chromosome_length_scaffolds")

def denovo_load_files(sample_id):
    data_path = denovo_hapfusion_output_path / sample_id
    if not (data_path / f"{sample_id}.hapfusion.txt").exists():
        data_path = denovo_hapfusion_output_path / sample_id / sample_id

    reads_df = pd.read_csv(
        str(data_path / f"{sample_id}.hapfusion.txt"),
        comment="#",
        delim_whitespace=True,
    )

    log_df = pd.read_csv(
        str(data_path / "hapfusion.log"),
        delim_whitespace=True,
        index_col=0,
    )

    candidates_df = pd.read_csv(
        str(data_path / "hapfusion_candidates.txt"),
        delim_whitespace=True,
    )

    return {"reads": reads_df, "summary": log_df, "candidates": candidates_df}

# %%
F = denovo_load_files("PD50523b")

# %%
F["summary"]
# Out:
#                                       chr1_RagTag  chr2_RagTag  chr3_RagTag  \
# ccs                                        277803       299310       251738
# lq_ccs                                      19737        18207        14262
# hq_ccs                                     258066       281103       237476
# unphased_ccs                                45152        50681        41361
# hap_consistent_ccs                         202524       218783       186610
# hap_inconsistent_ccs                        10390        11639         9505
# hap_denovo_phase_switch_mutation_ccs         9911        11301         9161
# hap_recombination_candidate_ccs              1767         1826         1504
# ambiguous                                     278          307          222
# crossover                                      12           17           10
# simple_gene_conversion                        118          125          103
# complex_gene_conversion                       143          162          144
#
#                                       chr4_RagTag  chr5_RagTag  chr6_RagTag  \
# ccs                                        246879       229346       213169
# lq_ccs                                      13673        13365        11925
# hq_ccs                                     233206       215981       201244
# unphased_ccs                                37862        36231        35397
# hap_consistent_ccs                         184981       170658       157482
# hap_inconsistent_ccs                        10363         9092         8365
# hap_denovo_phase_switch_mutation_ccs        10287         8818         8094
# hap_recombination_candidate_ccs              1651         1550         1328
# ambiguous                                     293          314          239
# crossover                                      10           11           15
# simple_gene_conversion                         95           94           93
# complex_gene_conversion                       203          143          136
#
#                                       chr7_RagTag  chr8_RagTag  chr9_RagTag  \
# ccs                                        196196       189668       147025
# lq_ccs                                      11982        11333        11308
# hq_ccs                                     184214       178335       135717
# unphased_ccs                                28498        31038        23266
# hap_consistent_ccs                         147537       139768       106899
# hap_inconsistent_ccs                         8179         7529         5552
# hap_denovo_phase_switch_mutation_ccs         7898         7416         5376
# hap_recombination_candidate_ccs              1350         1227          893
# ambiguous                                     257          233          147
# crossover                                       6            8            8
# simple_gene_conversion                         87           71           58
# complex_gene_conversion                       126          143           71
#
#                                       chr10_RagTag  ...  chr16_RagTag  \
# ccs                                         166608  ...         98521
# lq_ccs                                        9976  ...         12585
# hq_ccs                                      156632  ...         85936
# unphased_ccs                                 25642  ...         15190
# hap_consistent_ccs                          124125  ...         66987
# hap_inconsistent_ccs                          6865  ...          3759
# hap_denovo_phase_switch_mutation_ccs          6653  ...          3672
# hap_recombination_candidate_ccs               1131  ...           625
# ambiguous                                      208  ...           117
# crossover                                        7  ...             5
# simple_gene_conversion                          67  ...            41
# complex_gene_conversion                        112  ...            58
#
#                                       chr17_RagTag  chr18_RagTag  \
# ccs                                          85252        106128
# lq_ccs                                        5340          7027
# hq_ccs                                       79912         99101
# unphased_ccs                                 13559         14873
# hap_consistent_ccs                           63136         79647
# hap_inconsistent_ccs                          3217          4581
# hap_denovo_phase_switch_mutation_ccs          3091          4424
# hap_recombination_candidate_ccs                546           787
# ambiguous                                      105           169
# crossover                                        7            13
# simple_gene_conversion                          23            43
# complex_gene_conversion                         55            80
#
#                                       chr19_RagTag  chr20_RagTag  \
# ccs                                          50554         75084
# lq_ccs                                        4104          4785
# hq_ccs                                       46450         70299
# unphased_ccs                                  8380         11033
# hap_consistent_ccs                           36171         56157
# hap_inconsistent_ccs                          1899          3109
# hap_denovo_phase_switch_mutation_ccs          1814          2961
# hap_recombination_candidate_ccs                301           499
# ambiguous                                       44            94
# crossover                                        5             2
# simple_gene_conversion                          19            33
# complex_gene_conversion                         38            77
#
#                                       chr21_RagTag  chr22_RagTag  chrX_RagTag  \
# ccs                                          48788         51109         8445
# lq_ccs                                        5307          7887          670
# hq_ccs                                       43481         43222         7775
# unphased_ccs                                  7169          6380          454
# hap_consistent_ccs                           34257         34589         5927
# hap_inconsistent_ccs                          2055          2253         1394
# hap_denovo_phase_switch_mutation_ccs          2102          2366         1885
# hap_recombination_candidate_ccs                359           419          207
# ambiguous                                       82           105           51
# crossover                                        4             6            1
# simple_gene_conversion                          14            23            2
# complex_gene_conversion                         70           100          108
#
#                                       chrY_RagTag    total
# ccs                                          9376  3437343
# lq_ccs                                       6192   238970
# hq_ccs                                       3184  3198373
# unphased_ccs                                  948   538236
# hap_consistent_ccs                           2045  2522586
# hap_inconsistent_ccs                          191   137551
# hap_denovo_phase_switch_mutation_ccs          237   134089
# hap_recombination_candidate_ccs                38    22551
# ambiguous                                      18     4129
# crossover                                       2      184
# simple_gene_conversion                          2     1414
# complex_gene_conversion                         6     2425
#
# [12 rows x 25 columns]

# %% [markdown]
# # Calculate expected # of crossovers

# %% [markdown]
# ## Get read lengths and number (precalculated)

# %%
read_length_means = {}
read_length_stds = {}
read_numbers = {}

ccs_read_path = Path("/lustre/scratch126/casm/team154pc/sl17/03.sperm/01.data/02.ccs/")

for sample_id in sample_ids:
    count_path = ccs_read_path / sample_id / (sample_id + ".ccs.filtered.fastqc")
    d = open(count_path).read().strip().split()
    read_numbers[sample_id] = int(d[1])
    read_length_means[sample_id] = float(d[3])
    read_length_stds[sample_id] = float(d[4])

# %% [markdown]
# ## Calculate

# %%
def plot_obs_vs_exp(df):
    qs = scipy.stats.binom(n=df.n_reads, p=df.prob_crossover_read).ppf(np.array([0.25, 1-0.25])[:, np.newaxis])

    fig, ax = plt.subplots()
    ax.errorbar(        
        x = df.n_expected_mean,
        y = np.arange(len(df)),
        xerr = [df.n_expected_mean - qs[0], qs[1] - df.n_expected_mean],
        fmt='o',
    )

    ax.scatter(        
        df.n_observed,
        np.arange(len(df)),
        c = "C1",
    )

    ax.set_yticks(np.arange(len(df)))
    ax.set_yticklabels(df.sample_id)
    ax.set_ylabel("Sample ID")
    ax.set_xlabel("# of crossover events")
    ax.set_xlim(0, 800)

    for i in range(len(df)):
        ax.axhline(y = i, lw=0.05, c="black")

    return ax

# %%
num_events_mean = 27
num_events_low = 20
num_events_high = 36

genome_size = 3.1e9

# %% [markdown]
# ### For T2T

# %%
res = []

for sample_id in sample_ids:
    try:
        total_series = t2t_load_files(sample_id)["summary"]["total"]
        n_reads = total_series.loc["ccs"]
        n_obs = total_series.loc["crossover"]
        read_length_mean = read_length_means[sample_id]
        prob = (num_events_mean * read_length_mean / genome_size)

        res.append([
            sample_id,
            n_obs,
            n_reads * prob,
            n_reads, 
            prob,
            scipy.stats.binom.logcdf(k=n_obs, n=n_reads, p=prob),
            scipy.stats.binom.logsf(k=n_obs, n=n_reads, p=prob),
        ])
    except:
        pass

t2t_exp_df = pd.DataFrame(res, columns=["sample_id", "n_observed", "n_expected_mean", "n_reads", "prob_crossover_read", "logcdf", "logsf"])

# %%
plot_obs_vs_exp(t2t_exp_df).set_title("T2T reference")
# Out:
# Text(0.5, 1.0, 'T2T reference')

# %% [markdown]
# ### For hg19

# %%
res = []

for sample_id in sample_ids:
    try:
        total_series = hg19_load_files(sample_id)["summary"]["total"]
        n_reads = total_series.loc["ccs"]
        n_obs = total_series.loc["crossover"]
        read_length_mean = read_length_means[sample_id]
        prob = (num_events_mean * read_length_mean / genome_size)

        res.append([
            sample_id,
            n_obs,
            n_reads * prob,
            n_reads, 
            prob,
            scipy.stats.binom.logcdf(k=n_obs, n=n_reads, p=prob),
            scipy.stats.binom.logsf(k=n_obs, n=n_reads, p=prob),
        ])
    except:
        pass

hg19_exp_df = pd.DataFrame(res, columns=["sample_id", "n_observed", "n_expected_mean", "n_reads", "prob_crossover_read", "logcdf", "logsf"])

# %%
plot_obs_vs_exp(hg19_exp_df).set_title("hg19 reference")
# Out:
# Text(0.5, 1.0, 'hg19 reference')

# %% [markdown]
# ### For denovo

# %%
res = []

for sample_id in sample_ids:
    try:
        total_series = denovo_load_files(sample_id)["summary"]["total"]
        n_reads = total_series.loc["ccs"]
        n_obs = total_series.loc["crossover"]
        read_length_mean = read_length_means[sample_id]
        prob = (num_events_mean * read_length_mean / genome_size)

        res.append([
            sample_id,
            n_obs,
            n_reads * prob,
            n_reads, 
            prob,
            scipy.stats.binom.logcdf(k=n_obs, n=n_reads, p=prob),
            scipy.stats.binom.logsf(k=n_obs, n=n_reads, p=prob),
        ])
    except:
        pass

denovo_exp_df = pd.DataFrame(res, columns=["sample_id", "n_observed", "n_expected_mean", "n_reads", "prob_crossover_read", "logcdf", "logsf"])

# %%
plot_obs_vs_exp(denovo_exp_df).set_title("hifiasm reference")
# Out:
# Text(0.5, 1.0, 'hifiasm reference')

# %% [markdown]
# # Crossovers on sex chromosomes

# %%
res = []

for sample_id in sample_ids:
    row = []
    row.append(sample_id)

    # T2T
    try:
        summary = t2t_load_files(sample_id)["summary"]
        row.append(int(summary["chrX"].loc["crossover"]))
        row.append(int(summary["chrY"].loc["crossover"]))
    except:
        row.extend([np.nan, np.nan])

    # hg19
    try:
        summary = hg19_load_files(sample_id)["summary"]
        row.append(int(summary["X"].loc["crossover"]))
        row.append(int(summary["Y"].loc["crossover"]))
    except:
        row.extend([np.nan, np.nan])

    # Denovo
    try:
        summary = denovo_load_files(sample_id)["summary"]
        row.append(int(summary["chrX_RagTag"].loc["crossover"]))
        row.append(int(summary["chrY_RagTag"].loc["crossover"]))
    except:
        row.extend([np.nan, np.nan])

    res.append(row)

sex_df = pd.DataFrame(res, columns=["sample_id", "t2t_X", "t2t_Y", "hg19_X", "hg19_Y", "denovo_X", "denovo_Y"])

# %%
sex_df
# Out:
#   sample_id  t2t_X  t2t_Y  hg19_X  hg19_Y  denovo_X  denovo_Y
# 0  PD50477f      1      0       0       0       5.0       3.0
# 1  PD50519d      0      0       0       0       0.0       2.0
# 2  PD50508f      3      1       9       0       1.0       1.0
# 3  PD50523b      0      2       0       0       1.0       2.0
# 4  PD50521b      0      4       5      13       3.0      14.0
# 5  PD50508b      4      1       4       1       0.0       0.0
# 6  PD46180c      0      0       1       1       0.0       6.0
# 7  PD50521e      0      1       1      12       NaN       NaN
# 8  PD50489e      0      0       2       0       0.0       3.0

# %% [markdown]
# # Count GCs

# %%
summary
# Out:
#                                       chr1_RagTag  chr2_RagTag  chr3_RagTag  \
# ccs                                        244581       263575       226662
# lq_ccs                                      18285        17346        14641
# hq_ccs                                     226296       246229       212021
# unphased_ccs                                45224        50843        42144
# hap_consistent_ccs                         174314       188442       163823
# hap_inconsistent_ccs                         6758         6944         6054
# hap_denovo_phase_switch_mutation_ccs         6313         6346         5515
# hap_recombination_candidate_ccs              1307         1354         1219
# ambiguous                                     215          207          153
# crossover                                      10            7           14
# simple_gene_conversion                         69           56           60
# complex_gene_conversion                       113           82           76
#
#                                       chr4_RagTag  chr5_RagTag  chr6_RagTag  \
# ccs                                        213264       209615       190160
# lq_ccs                                      13628        13414        11965
# hq_ccs                                     199636       196201       178195
# unphased_ccs                                39981        38988        35109
# hap_consistent_ccs                         153850       151605       137844
# hap_inconsistent_ccs                         5805         5608         5242
# hap_denovo_phase_switch_mutation_ccs         5504         5063         4808
# hap_recombination_candidate_ccs              1188         1114         1048
# ambiguous                                     205          195          185
# crossover                                       7            6            5
# simple_gene_conversion                         63           66           46
# complex_gene_conversion                        88           76           78
#
#                                       chr7_RagTag  chr8_RagTag  chr9_RagTag  \
# ccs                                        167045       167980       131913
# lq_ccs                                      11541        11354        11270
# hq_ccs                                     155504       156626       120643
# unphased_ccs                                30790        30316        23066
# hap_consistent_ccs                         120214       121515        94132
# hap_inconsistent_ccs                         4500         4795         3445
# hap_denovo_phase_switch_mutation_ccs         4037         4525         2988
# hap_recombination_candidate_ccs               883          898          743
# ambiguous                                     149          155          104
# crossover                                       3            5            6
# simple_gene_conversion                         47           45           42
# complex_gene_conversion                        59           69           51
#
#                                       chr10_RagTag  ...  chr16_RagTag  \
# ccs                                         151586  ...         75490
# lq_ccs                                       10449  ...          7578
# hq_ccs                                      141137  ...         67912
# unphased_ccs                                 26615  ...         13263
# hap_consistent_ccs                          110059  ...         52343
# hap_inconsistent_ccs                          4463  ...          2306
# hap_denovo_phase_switch_mutation_ccs          4136  ...          2233
# hap_recombination_candidate_ccs                899  ...           379
# ambiguous                                      147  ...            55
# crossover                                        2  ...             2
# simple_gene_conversion                          47  ...            22
# complex_gene_conversion                         91  ...            27
#
#                                       chr17_RagTag  chr18_RagTag  \
# ccs                                          65582         94288
# lq_ccs                                        4762          6017
# hq_ccs                                       60820         88271
# unphased_ccs                                 11909         15853
# hap_consistent_ccs                           47017         69736
# hap_inconsistent_ccs                          1894          2682
# hap_denovo_phase_switch_mutation_ccs          1723          2436
# hap_recombination_candidate_ccs                371           544
# ambiguous                                       80           103
# crossover                                        7             6
# simple_gene_conversion                          16            37
# complex_gene_conversion                         30            31
#
#                                       chr19_RagTag  chr20_RagTag  \
# ccs                                          37535         67479
# lq_ccs                                        2924          4429
# hq_ccs                                       34611         63050
# unphased_ccs                                  6095         12342
# hap_consistent_ccs                           27372         48831
# hap_inconsistent_ccs                          1144          1877
# hap_denovo_phase_switch_mutation_ccs          1209          1783
# hap_recombination_candidate_ccs                272           347
# ambiguous                                       58            54
# crossover                                        0             3
# simple_gene_conversion                           4            24
# complex_gene_conversion                         36            31
#
#                                       chr21_RagTag  chr22_RagTag  chrX_RagTag  \
# ccs                                          48154         45403         7346
# lq_ccs                                        5968          6434          526
# hq_ccs                                       42186         38969         6820
# unphased_ccs                                  7767          7106          354
# hap_consistent_ccs                           32899         30358         5648
# hap_inconsistent_ccs                          1520          1505          818
# hap_denovo_phase_switch_mutation_ccs          1343          1707         1013
# hap_recombination_candidate_ccs                387           337          169
# ambiguous                                       91            99           41
# crossover                                        3             3            0
# simple_gene_conversion                          14             9            5
# complex_gene_conversion                         54            73           81
#
#                                       chrY_RagTag    total
# ccs                                          6327  3011062
# lq_ccs                                       2413   220981
# hq_ccs                                       3914  2790081
# unphased_ccs                                  623   547147
# hap_consistent_ccs                           2484  2158800
# hap_inconsistent_ccs                          807    84134
# hap_denovo_phase_switch_mutation_ccs         3666    81027
# hap_recombination_candidate_ccs               472    17051
# ambiguous                                     219     3059
# crossover                                       3      112
# simple_gene_conversion                          3      835
# complex_gene_conversion                       221     1596
#
# [12 rows x 25 columns]

# %%
res = []

for sample_id in sample_ids:
    row = []
    row.append(sample_id)

    # T2T
    try:
        summary = t2t_load_files(sample_id)["summary"]
        row.append(int(summary["total"].loc["simple_gene_conversion"]))
        row.append(int(summary["total"].loc["complex_gene_conversion"]))
    except:
        row.extend([np.nan, np.nan])

    # hg19
    try:
        summary = hg19_load_files(sample_id)["summary"]
        row.append(int(summary["total"].loc["simple_gene_conversion"]))
        row.append(int(summary["total"].loc["complex_gene_conversion"]))
    except:
        row.extend([np.nan, np.nan])

    # Denovo
    try:
        summary = denovo_load_files(sample_id)["summary"]
        row.append(int(summary["total"].loc["simple_gene_conversion"]))
        row.append(int(summary["total"].loc["complex_gene_conversion"]))
    except:
        row.extend([np.nan, np.nan])

    res.append(row)

gc_df = pd.DataFrame(res, columns=["sample_id", "t2t_GC_simple", "t2t_GC_complex", "hg19_GC_simple", "hg19_GC_complex", "denovo_GC_simple", "denovo_GC_complex"])

# %%
gc_df
# Out:
#   sample_id  t2t_GC_simple  t2t_GC_complex  hg19_GC_simple  hg19_GC_complex  \
# 0  PD50477f           1214            3945            1167            11243
# 1  PD50519d            938            3210             972             9342
# 2  PD50508f           1181            6439            1129            10523
# 3  PD50523b           1392            3821            1365            10055
# 4  PD50521b           1313           13443            1375            22863
# 5  PD50508b           1703            7221            1671            12175
# 6  PD46180c           1440            7794            1343            14646
# 7  PD50521e           1742            8328            1647            15935
# 8  PD50489e            793            1718             788             9552
#
#    denovo_GC_simple  denovo_GC_complex
# 0              1215               3874
# 1               970               2199
# 2               230                611
# 3              1414               2425
# 4              1417               7258
# 5               873               1455
# 6              1482               6345
# 7              1210               2117
# 8               835               1596

# %% [markdown]
# # Check if crossovers are consistent

# %%
rate_maps = {}
for chrom in aut_chrom_names:
    rate_maps[chrom] = \
        msprime.RateMap.read_hapmap(
            open(f"/lustre/scratch126/casm/team154pc/sl17/03.sperm/01.data/07.references/04.genetic_maps/02.T2T_lifted_Bherer_etal_SexualDimorphismRecombination/Refined_EUR_genetic_map_b37/male_{chrom}_genetic_map.txt"),
            sequence_length=liftover.T2T_chromosome_sizes_in_bp[chrom],
        )

# %%
# Parse the reads dataframe and add the intersection with the lifted accessibility mask
def extend_reads_df(reads_df):
    reads_df["read_chrom"] = reads_df[0].str.split(':').str[0]
    reads_df["read_start_pos_0based"] = reads_df[0].str.split(':').str[1].str.split('-').str[0].astype(int)
    reads_df["read_end_pos_0based"] = reads_df[0].str.split(':').str[1].str.split('-').str[1].astype(int)

    return annotate.annonate_with_mappability_mask(reads_df)

# %%
def get_cm_ranges(sample_id):
    reads_df = t2t_load_files(sample_id)["reads"]
    reads_df = extend_reads_df(reads_df)

    dfs = []
    cms = []
    
    for chrom in aut_chrom_names:
        print(chrom)
        rate_map = rate_maps[chrom]

        crossovers_df = reads_df[reads_df[0].str.startswith(f"{chrom}:") & (reads_df[4] == "CO")]
        dfs.append(crossovers_df)

        range_col = crossovers_df[0].str.split(':').str[1]
        start_poses_0based = range_col.str.split('-').str[0].astype(int) - 1
        end_poses_0based = range_col.str.split('-').str[1].astype(int)                
        start_poses_cm = rate_map.get_cumulative_mass(start_poses_0based.values)
        end_poses_cm = rate_map.get_cumulative_mass(end_poses_0based.values)
        cms.append((end_poses_cm - start_poses_cm) * 1e6)

        #return crossovers_df

    return dfs, cms
    
dfs, cms = get_cm_ranges(sample_id)
# Out:
# chr1
# chr2
# chr3
# chr4
# chr5
# chr6
# chr7
# chr8
# chr9
# chr10
# chr11
# chr12
# chr13
# chr14
# chr15
# chr16
# chr17
# chr18
# chr19
# chr20
# chr21
# chr22

# %%
df = pd.concat(dfs)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
    display(df[[0, 1, 4, "accessible_ratio"]])
# Out:
#                                0                                    1   4  \
# 153       chr1:16406144-16429403   m64174e_220620_110709/52561002/ccs  CO
# 155       chr1:16413025-16428274   m64094e_220715_151527/47186949/ccs  CO
# 168       chr1:16424618-16445834   m64174e_220620_110709/14944360/ccs  CO
# 169       chr1:16426051-16440322  m64094e_220717_002414/120261263/ccs  CO
# 170       chr1:16426313-16435589   m64174e_220620_110709/49219956/ccs  CO
# 339       chr1:57184965-57206053   m64094e_220715_151527/84804594/ccs  CO
# 385       chr1:65453916-65470676    m64174e_220620_110709/1704631/ccs  CO
# 510       chr1:86319215-86332066   m64174e_220620_110709/56165494/ccs  CO
# 716     chr1:120841578-120848318   m64094e_220717_002414/38142195/ccs  CO
# 737     chr1:127494582-127500034  m64174e_220620_110709/141560164/ccs  CO
# 740     chr1:127704434-127719107   m64174e_220620_110709/64883108/ccs  CO
# 783     chr1:145173622-145180236   m64094e_220715_151527/62260401/ccs  CO
# 1014    chr1:186340351-186360953    m64094e_220715_151527/3540907/ccs  CO
# 8631           0.000000
# 8632           0.000000
# 8635           0.000000
# 8638           0.000000
# 8640           0.000000
# 8655           0.000000
# 8757           0.955908
# 8781           0.962612
# 8845           0.674056
# 8848           0.530736
# 8985           0.450840
# 8986           0.527854
# 8988           0.532432
# 8989           0.500099
# 8991           0.524508
# 9125           0.986846
# 9356           0.846041
# 9594           0.974023
# 9750           0.999671
# 9828           0.691605
# 9900           0.990173
# 10078          0.951704
# 10215          0.255336
# 10216          0.322641
# 10217          0.281996
# 10218          0.553211
# 10380          0.304944
# 10519          0.314802
# 10520          0.232027
# 10586          0.981830
# 10645          0.642778
# 10725          0.881062
# 10935          0.987977
# 10937          0.765291
# 10938          0.715857
# 10939          0.631416
# 10940          0.466771
# 10941          0.403715
# 11550          0.240520
# 11828          1.855571
# 12250          0.991876
# 12400          0.997074
# 12432          0.999742
# 12542          0.860042
# 12859          0.981241
# 12984          0.981281
# 13020          0.990717
# 13029          0.600792
# 13388          0.994298
# 13609          0.005797
# 13622          0.581447
# 13623          0.573088
# 13690          0.040544
# 13691          0.030471
# 13931          0.998978
# 13933          1.000000
# 13995          0.965983
# 14282          0.981610
# 14440          0.071331
# 14552          0.024062
# 15286          0.970929
# 15352          0.953091
# 15465          0.998340
# 15769          0.645200
# 15775          0.892048
# 15812          0.985705
# 15861          0.915882
# 15899          0.529462
# 16241          0.987405
# 16275          0.958650
# 16309          0.803063
# 16536          0.000000
# 16537          0.059386
# 16630          0.929981
# 16699          0.997193
# 16762          0.759805
# 16763          0.664601
# 16765          0.560510
# 16766          0.451416
# 16767          0.373582
# 16788          0.000000
# 17155          0.019591
# 17158          0.052740
# 17159          0.029195
# 17214          0.001650
# 17351          0.000000
# 17352          0.000000
# 17353          0.000000
# 17354          0.000000
# 17446          0.982818
# 17676          0.000000
# 17687          0.000000

# %% [markdown]
# # How many reads were mapped?

# %%
sample_id = sample_ids[0]
print(sample_id)
# Out:
# PD50477f

# %%
total_read_numbers = {}   # Different than from the fastqc for some reason - this will be taken from the bam
mapped_read_numbers = {}
for sample_id in sample_ids:
    mapped_read_numbers[sample_id] = 0
    
    F = pysam.AlignmentFile(
        f"/lustre/scratch126/casm/team154pc/sl17/03.sperm/02.results/01.read_alignment/01.ccs/03.T2T-CHM13/{sample_id}/chm13.{sample_id}.minimap2.primary_alignments.sorted.bam"
    )

    total_read_numbers[sample_id] = F.nocoordinate
    all_index_stats = F.get_index_statistics()

    for index_stats in all_index_stats:
        total_read_numbers[sample_id] += index_stats.total
        if index_stats.contig in chrom_names:
            mapped_read_numbers[sample_id] += index_stats.mapped

# %%
read_number_stats_df = pd.DataFrame(
    {
        "sample_id": sample_ids,
        "n_all_reads": [total_read_numbers[sample_id] for sample_id in sample_ids],
        "n_mapped_reads": [mapped_read_numbers[sample_id] for sample_id in sample_ids],
    }
)

read_number_stats_df = read_number_stats_df.merge(
    t2t_exp_df[["sample_id", "n_reads"]].rename(columns={"n_reads": "n_hapfusion_reads"})
)

read_number_stats_df["mapped_to_all_ratio"] = read_number_stats_df["n_mapped_reads"] / read_number_stats_df["n_all_reads"]
read_number_stats_df["hapfusion_to_mapped_ratio"] = read_number_stats_df["n_hapfusion_reads"] / read_number_stats_df["n_mapped_reads"]


display(read_number_stats_df)
# Out:
#   sample_id  n_all_reads  n_mapped_reads  n_hapfusion_reads  \
# 0  PD50477f      7185241         5671375            4066022
# 1  PD50519d      5353906         4971177            3288910
# 2  PD50508f      3040994         2778593            2109867
# 3  PD50523b      4741878         4740213            3429042
# 4  PD50521b      6294384         6293834            4765229
# 5  PD50508b      3947659         3947252            2958538
# 6  PD46180c      5936129         5819160            4351397
# 7  PD50521e      6168195         6125876            4466513
# 8  PD50489e      6065965         6064631            3003323
#
#    mapped_to_all_ratio  hapfusion_to_mapped_ratio
# 0             0.789309                   0.716938
# 1             0.928514                   0.661596
# 2             0.913712                   0.759329
# 3             0.999649                   0.723394
# 4             0.999913                   0.757127
# 5             0.999897                   0.749518
# 6             0.980295                   0.747771
# 7             0.993139                   0.729122
# 8             0.999780                   0.495219

# %%
display(read_number_stats_df[["sample_id", "n_all_reads", "n_mapped_reads", "mapped_to_all_ratio"]])
# Out:
#   sample_id  n_all_reads  n_mapped_reads  mapped_to_all_ratio
# 0  PD50477f      7185241         5671375             0.789309
# 1  PD50519d      5353906         4971177             0.928514
# 2  PD50508f      3040994         2778593             0.913712
# 3  PD50523b      4741878         4740213             0.999649
# 4  PD50521b      6294384         6293834             0.999913
# 5  PD50508b      3947659         3947252             0.999897
# 6  PD46180c      5936129         5819160             0.980295
# 7  PD50521e      6168195         6125876             0.993139
# 8  PD50489e      6065965         6064631             0.999780

# %%
X = pysam.AlignmentFile(
        f"/lustre/scratch126/casm/team154pc/sl17/03.sperm/02.results/01.read_alignment/01.ccs/03.T2T-CHM13/PD50477f/chm13.PD50477f.minimap2.primary_alignments.sorted.bam"
)

# %%
t2t_access_mask = pybedtools.BedTool("/lustre/scratch126/casm/team154pc/sl17/03.sperm/01.data/07.references/05.accessibility_masks/01.T2T/combined_mask.bed.gz")

# %%
reads_df = pd.DataFrame(
    [[segment.reference_name, segment.reference_start, segment.reference_end] for segment in X.fetch("chr1")],
    columns=["read_chrom", "read_start_pos_1based", "read_end_pos_1based"]
)

reads_df["read_start_pos_0based"] = reads_df["read_start_pos_1based"] - 1
reads_df["read_end_pos_0based"] = reads_df["read_end_pos_1based"]
reads_df = reads_df.drop(columns=["read_start_pos_1based", "read_end_pos_1based"])

reads_df = reads_df.sample(frac=0.1)

reads_bed = pybedtools.BedTool.from_dataframe(reads_df)

# %%
intersection_df = (t2t_access_mask
    .intersect(reads_bed, wb=True)
    .to_dataframe()
    .set_axis(["chrom", "start", "end", "read_chrom", "read_start_pos_0based", "read_end_pos_0based"], axis=1)
)

intersection_df = (intersection_df
    .assign(interval_length = lambda df: df["end"] - df["start"])
    .groupby(by=["read_chrom", "read_start_pos_0based", "read_end_pos_0based"])[["interval_length"]]
    .sum()
    .reset_index()        
    .merge(reads_df, on=["read_chrom", "read_start_pos_0based", "read_end_pos_0based"], how="right")
    .fillna({"interval_length": 0})
    .assign(read_length = lambda df: df["read_end_pos_0based"] - df["read_start_pos_0based"])
    .assign(accessible_ratio = lambda df: df["interval_length"] / df["read_length"].astype(float))   
)

# %%
intersection_df
# Out:
#       read_chrom  read_start_pos_0based  read_end_pos_0based  interval_length  \
# 0           chr1              179029498            179045296          14331.0
# 1           chr1                7002628              7013699           9664.0
# 2           chr1              153067861            153082521          10317.0
# 3           chr1              143267611            143281063              0.0
# 4           chr1               26600952             26611416           9790.0
# ...          ...                    ...                  ...              ...
# 47887       chr1              213235057            213250326          15258.0
# 47888       chr1              140999421            141009701              0.0
# 47889       chr1               75103679             75117721          14034.0
# 47890       chr1              165010737            165029798          18750.0
# 47891       chr1              236412174            236423704          11499.0
#
#        read_length  accessible_ratio
# 0            15798          0.907140
# 1            11071          0.872911
# 2            14660          0.703752
# 3            13452          0.000000
# 4            10464          0.935589
# ...            ...               ...
# 47887        15269          0.999280
# 47888        10280          0.000000
# 47889        14042          0.999430
# 47890        19061          0.983684
# 47891        11530          0.997311
#
# [47892 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(4,3))
ax.hist(
    intersection_df.accessible_ratio,
    bins=25,    
);
ax.set_xlabel("% accessible");
ax.set_ylabel("# reads")
ax.set_title(f"{sample_id}, chr1");

# %%
(intersection_df.accessible_ratio>0.5).mean()
# Out:
# 0.8648626075336173

# %%
fig, ax = plt.subplots(figsize=(4,3))
qs = np.linspace(0, 100, 21)
ys = np.percentile(intersection_df.accessible_ratio, q=qs)
ax.plot(ys, 100-qs)
ax.set_xlabel("% accessible")
ax.set_ylabel("percentile")
ax.yaxis.set_major_formatter(mtick.PercentFormatter())

# %% [markdown]
# # Annotate interval with recombination probability, and detectability

# %%
# %%time
def annotate_intervals(
    sample_id,
    chrom,
    starts_0based, 
    ends_0based,
):
    # Bed of all intervals
    reads_df = \
        pd.DataFrame({
            "sample_id": sample_id,
            "read_chrom": chrom,
            "read_start_pos_0based":starts_0based,
            "read_end_pos_0based": ends_0based,
        })

    # Add annotations
    reads_df = annotate.annonate_with_mappability_mask(reads_df)
    reads_df = annotate.annotate_with_cm_ranges(reads_df) 
    reads_df = annotate.annotate_with_crossover_detection_prob(
        reads_df,
        annotate.get_all_hets(sample_id, chrom)
    )   

    return reads_df
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.2 µs

# %% [markdown]
# ## What is the random distribution of cMs?

# %%
# %%time

rng = np.random.default_rng()

sample_id = "PD46180c"
chrom = "chr1"
n_fake_reads = 10000
fake_read_length = int(read_length_means[sample_id])

# Create random positions
random_positions = rng.integers(low = 0, high = liftover.T2T_chromosome_sizes_in_bp[chrom], size = n_fake_reads)

# Remove if too close to the edge
random_positions = random_positions[random_positions + fake_read_length < liftover.T2T_chromosome_sizes_in_bp[chrom]]

fake_reads_df = annotate_intervals(
    sample_id,
    chrom,
    starts_0based = random_positions, 
    ends_0based = random_positions + fake_read_length,
)
    
fake_reads_df
# Out:
# CPU times: user 1.59 s, sys: 200 ms, total: 1.79 s
# Wall time: 4.62 s
#      read_chrom  read_start_pos_0based  read_end_pos_0based  \
# 0          chr1              149176890            149193270
# 1          chr1              210195105            210211485
# 2          chr1                6147341              6163721
# 3          chr1               70654553             70670933
# 4          chr1              146168960            146185340
# ...         ...                    ...                  ...
# 9993       chr1              166747611            166763991
# 9994       chr1              102028644            102045024
# 9995       chr1               79665907             79682287
# 9996       chr1               24000726             24017106
# 9997       chr1               44672047             44688427
#
#       snp_pos_0based_min  snp_pos_0based_max  interval_length sample_id  \
# 0                    NaN                 NaN          16019.0  PD46180c
# 1            210195145.0         210210354.0          15670.0  PD46180c
# 2              6150509.0           6160934.0          12785.0  PD46180c
# 3             70655227.0          70668839.0          16367.0  PD46180c
# 4            146182982.0         146185243.0             17.0  PD46180c
# ...                  ...                 ...              ...       ...
# 9993         166749318.0         166758836.0          16288.0  PD46180c
# 9994         102029993.0         102039972.0          16309.0  PD46180c
# 9995          79666128.0          79681697.0          16031.0  PD46180c
# 9996          24001475.0          24005675.0          15971.0  PD46180c
# 9997          44672313.0          44687726.0          11672.0  PD46180c
#
#       read_length  accessible_ratio        cM  prob_crossover  \
# 0           16380          0.977961  0.000264        0.000003
# 1           16380          0.956654  0.002296        0.000023
# 2           16380          0.780525  0.000173        0.000002
# 3           16380          0.999206  0.000213        0.000002
# 4           16380          0.001038  0.000974        0.000010
# ...           ...               ...       ...             ...
# 9993        16380          0.994383  0.014942        0.000149
# 9994        16380          0.995665  0.005223        0.000052
# 9995        16380          0.978694  0.000169        0.000002
# 9996        16380          0.975031  0.005036        0.000050
# 9997        16380          0.712576  0.000927        0.000009
#
#       phased_snps_span  crossover_detection_prob
# 0                  NaN                  0.000000
# 1              15209.0                  0.928510
# 2              10425.0                  0.636447
# 3              13612.0                  0.831013
# 4               2261.0                  0.138034
# ...                ...                       ...
# 9993            9518.0                  0.581074
# 9994            9979.0                  0.609219
# 9995           15569.0                  0.950488
# 9996            4200.0                  0.256410
# 9997           15413.0                  0.940965
#
# [9998 rows x 13 columns]

# %%
fig, axs = plt.subplots(1, 3, figsize=(14, 3))

sns.histplot(
    fake_reads_df["accessible_ratio"],
    bins=np.linspace(0, 1, 50),
    stat="proportion",
    ax=axs[0],
)
axs[0].set_title("Accessible ratio");
axs[0].set_xlabel("Ratio");

sns.histplot(
    [fake_reads_df["cM"].values, fake_reads_df["cM"][fake_reads_df["accessible_ratio"]>0.5].values], 
    bins=np.linspace(0, 0.2, 20),
    multiple="dodge",
    shrink=0.8,
    stat="proportion",
    common_norm=False,
    ax=axs[1],
)
axs[1].legend(["All", "Only >50% accessible"]);
axs[1].set_title("Read length in cM");
axs[1].set_xlabel("Length in cM");

sns.histplot(
    [fake_reads_df["prob_crossover"].values, fake_reads_df["prob_crossover"][fake_reads_df["accessible_ratio"]>0.5].values], 
    bins=np.linspace(0, 1e-4, 25),
    multiple="dodge",
    shrink=0.8,
    stat="proportion",
    common_norm=False,
    ax=axs[2],
)

axs[2].legend(["All", "Only >50% accessible"]);
axs[2].set_title("Probabilty of crossover in interval");
axs[2].set_xlabel("Probability");
axs[2].ticklabel_format(axis="x", style="sci", scilimits=(0,0))

# %% [markdown]
# ## Are random reads distributed differently than crossosver calls?

# %%
F = t2t_load_files(sample_id)

# %%
# %%time
true_reads_df = extend_reads_df(F["reads"])
# Out:
# CPU times: user 1.13 s, sys: 168 ms, total: 1.3 s
# Wall time: 5.49 s

# %%
subset_true_reads_df = true_reads_df[(true_reads_df.read_chrom == chrom) & (true_reads_df[4] == "CO")]

# %%
true_reads_chrom_df = annotate_intervals(
    sample_id,
    chrom,
    starts_0based = subset_true_reads_df["read_start_pos_0based"], 
    ends_0based = subset_true_reads_df["read_end_pos_0based"],
)

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))

sns.histplot(
    [
        fake_reads_df["accessible_ratio"].values, 
        true_reads_chrom_df["accessible_ratio"].values
    ]
    ,
    bins=np.linspace(0, 1, 25),
    multiple="dodge",
    shrink=0.8,
    stat="proportion",
    common_norm=False,
    ax=axs[0],
)
axs[0].legend(["Random reads", "Called crossovers"]);
axs[0].set_title("Accessible ratio");
axs[0].set_xlabel("Ratio");

sns.histplot(
    [
        fake_reads_df["cM"][fake_reads_df["accessible_ratio"]>0.5].values,
        true_reads_chrom_df["cM"][true_reads_chrom_df["accessible_ratio"]>0.5].values,
    ],
    bins=np.linspace(0, 0.5, 25),
    multiple="dodge",
    shrink=0.8,
    stat="proportion",
    common_norm=False,
    ax=axs[1],
)
axs[1].legend(["Random reads", "Called crossovers"]);
axs[1].set_title("Read length in cM \n(>50% accessible)");
axs[1].set_xlabel("Length in cM");

sns.histplot(
    [
        fake_reads_df["prob_crossover"][fake_reads_df["accessible_ratio"]>0.5].values,
        true_reads_chrom_df["prob_crossover"][true_reads_chrom_df["accessible_ratio"]>0.5].values,
    ], 
    bins=np.linspace(0, 5e-3, 25),
    multiple="dodge",
    shrink=0.8,
    stat="proportion",
    common_norm=False,
    ax=axs[2],
)
axs[2].legend(["Random reads", "Called crossovers"]);
axs[2].set_title("Probabilty of crossover in read \n(>50% accessible)");
axs[2].set_xlabel("Probability");
axs[2].ticklabel_format(axis="x", style="sci", scilimits=(0,0))

# %%
true_reads_chrom_df["prob_crossover"][true_reads_chrom_df["accessible_ratio"]>0.5].values.mean()
# Out:
# 0.0008829963088411199

# %%
true_reads_chrom_df["cM"][true_reads_chrom_df["accessible_ratio"]>0.5].values.mean()
# Out:
# 0.08839426698870996

# %%
fake_reads_df["cM"][fake_reads_df["accessible_ratio"]>0.5].mean()
# Out:
# 0.014849926857595837

# %%
true_reads_chrom_df["cM"][true_reads_chrom_df["accessible_ratio"]>0.5].mean()
# Out:
# 0.08839426698870996

# %% [markdown]
# # Are badly lifted intervals from genetic map in accessibility mask?

# %%
sample_id = sample_ids[0]

chrom = aut_chrom_names[0]

dfs = []
for chrom in aut_chrom_names:
    df = annotate_intervals(
        sample_id,
        chrom,
        starts_0based = rate_maps[chrom].left[rate_maps[chrom].rate == 0].astype(int), 
        ends_0based = rate_maps[chrom].right[rate_maps[chrom].rate == 0].astype(int),
    )
    dfs.append(df)

badly_lifted_chrom_df = pd.concat(dfs)

# %%
plt.hist(
    badly_lifted_chrom_df["accessible_ratio"],
    bins=np.linspace(0,1,50),
);
plt.title("% accessible for badly lifted intervals");

# %%
plt.hist(
    badly_lifted_chrom_df["accessible_ratio"],
    bins=np.linspace(0,1,50),
    weights = badly_lifted_chrom_df["accessible_ratio"] * badly_lifted_chrom_df["read_length"],
);
plt.title("% accessible for badly lifted intervals, \n weighted by interval length");

# %%
(badly_lifted_chrom_df.read_length * badly_lifted_chrom_df.accessible_ratio).sum()
# Out:
# 25998975.0

# %%
badly_lifted_chrom_df[badly_lifted_chrom_df.accessible_ratio > 0.5].read_length.sum()
# Out:
# 9622907

# %% [markdown]
# # Check positions of hets in reads

# %%
(np.isnan(fake_reads_df.phased_snps_span) | (fake_reads_df.phased_snps_span < 500)).mean()
# Out:
# 0.3882776555311062

# %%
plt.hist(
    [
        fake_reads_df["crossover_detection_prob"][fake_reads_df.accessible_ratio > 0.5], 
        true_reads_chrom_df["crossover_detection_prob"][true_reads_chrom_df.accessible_ratio > 0.5]
    ],
    bins=np.linspace(0,1,25),
    density=True,
);

# %% [markdown]
# # Now calculate accurately the expected number of detected events

# %%
def calculate_expected_number(sample_id, just_return_df=False):
    dfs = []
    for chrom in aut_chrom_names:
        dfs.append(pd.read_csv(
            f"/lustre/scratch126/casm/team154pc/sl17/03.sperm/02.results/01.read_alignment/01.ccs/03.T2T-CHM13/{sample_id}/fake_reads_for_qc/{chrom}.csv",
        ))
    fake_reads_df = pd.concat(dfs)

    if just_return_df:
        return fake_reads_df

    p = (fake_reads_df["accessible_ratio"] > 0.5).mean()
    p *= (fake_reads_df
        .loc[lambda df: df["accessible_ratio"] > 0.5]
        .assign(final_prob = lambda df: df["prob_crossover"] * df["crossover_detection_prob"])
        ["final_prob"].mean()
    )

    n = mapped_read_numbers[sample_id]

    return n*p

# %%
res = []

for sample_id in sample_ids:
    try:
        n_reads = mapped_read_numbers[sample_id]

        total_series = t2t_load_files(sample_id)["summary"]["total"]        
        n_obs = total_series.loc["crossover"]

        exp = calculate_expected_number(sample_id)

        res.append([
            sample_id,
            n_obs,
            exp,
        ])
    except:
        pass

better_t2t_exp_df = pd.DataFrame(res, columns=["sample_id", "n_observed", "n_expected"])

# %%
better_t2t_exp_df
# Out:
#   sample_id  n_observed  n_expected
# 0  PD50477f         282  320.989750
# 1  PD50519d         173  235.543216
# 2  PD50508f         334  258.941498
# 3  PD50523b         300  311.538399
# 4  PD50521b         666  584.331066
# 5  PD50508b         428  360.216254
# 6  PD46180c         468  486.217744
# 7  PD50521e         572  388.270179
# 8  PD50489e         157  161.652089

# %%
def plot_better_obs_vs_exp(df):
    qs = scipy.stats.poisson(mu=df.n_expected).ppf(np.array([0.25, 1-0.25])[:, np.newaxis])

    fig, ax = plt.subplots()
    ax.errorbar(        
        x = df.n_expected,
        y = np.arange(len(df)),
        xerr = [df.n_expected - qs[0], qs[1] - df.n_expected],
        fmt='o',
    )

    ax.scatter(        
        df.n_observed,
        np.arange(len(df)),
        c = "C1",
    )

    ax.set_yticks(np.arange(len(df)))
    ax.set_yticklabels(df.sample_id)
    ax.set_ylabel("Sample ID")
    ax.set_xlabel("# of crossover events")
    ax.set_xlim(0, 800)

    for i in range(len(df)):
        ax.axhline(y = i, lw=0.05, c="black")

    return ax

# %%
plot_better_obs_vs_exp(better_t2t_exp_df.sort_values("sample_id", ascending=False))
# Out:
# <Axes: xlabel='# of crossover events', ylabel='Sample ID'>

# %% [markdown]
# ## Look at bit deeper at the components per sample

# %% [markdown]
# ## Load all real called CO events, filter

# %%
# %%time

true_reads_dfs = {}

for sample_id in sample_ids:
    print(sample_id)

    F = t2t_load_files(sample_id)
    reads_df = F["reads"]
    
    reads_df["read_chrom"] = reads_df[0].str.split(':').str[0]
    reads_df["read_start_pos_0based"] = reads_df[0].str.split(':').str[1].str.split('-').str[0].astype(int)
    reads_df["read_end_pos_0based"] = reads_df[0].str.split(':').str[1].str.split('-').str[1].astype(int)

    reads_df = reads_df[(reads_df[4] == "CO")]

    reads_df = annotate.annonate_with_mappability_mask(reads_df)
    reads_df = annotate.annotate_with_cm_ranges(reads_df) 
    reads_df = annotate.annotate_with_crossover_detection_prob(
        reads_df,
        annotate.get_all_hets(sample_id)
    )

    true_reads_dfs[sample_id] = reads_df
# Out:
# PD50477f
# PD50519d
# PD50508f
# PD50523b
# PD50521b
# PD50508b
# PD46180c
# PD50521e
# PD50489e
# CPU times: user 2min 28s, sys: 9.36 s, total: 2min 38s
# Wall time: 3min 11s

# %% [markdown]
# ### Pr(read to be >50% accessible)

# %%
fake_reads_dfs = {}

for sample_id in sample_ids:
    fake_reads_dfs[sample_id ]= calculate_expected_number(sample_id, just_return_df=True)

# %%
for sample_id in sample_ids:
    print(sample_id, (fake_reads_dfs[sample_id]["accessible_ratio"] > 0.5).mean())
# Out:
# PD50477f 0.8804837023230441
# PD50519d 0.8841258296208746
# PD50508f 0.879154353262105
# PD50523b 0.8834386507250989
# PD50521b 0.8826310286831219
# PD50508b 0.8806709700881898
# PD46180c 0.8791998181404864
# PD50521e 0.8786363636363637
# PD50489e 0.8779434494044913

# %% [markdown]
# ### Pr(read overlaps event)

# %%
fig, axs = plt.subplots(3, 3, figsize=(9,9))

for ax, sample_id in zip(axs.ravel(), sample_ids):
    fake_reads_df = fake_reads_dfs[sample_id]

    sns.histplot(
        [
            pd.Series(fake_reads_df["cM"][fake_reads_df["accessible_ratio"]>0.5].values, name="Random reads"),
            pd.Series(true_reads_dfs[sample_id]["cM"][true_reads_dfs[sample_id]["accessible_ratio"]>0.5].values, name="Called crossovers"),
        ],
        bins=np.linspace(0, 0.5, 25),
        multiple="dodge",
        shrink=0.8,
        stat="proportion",
        common_norm=False,
        ax=ax,
    )
    #ax.legend(["Random reads", "Called crossovers"]);
    #ax.set_title("Read length in cM \n(>50% accessible)");
    ax.set_title(sample_id);
    #ax.set_xlabel("Length in cM");

fig.subplots_adjust()

# %%
for sample_id in sorted(sample_ids):
    fake_reads_df = fake_reads_dfs[sample_id]
    p = (fake_reads_df
        .loc[lambda df: df["accessible_ratio"] > 0.5]
        .assign(final_prob = lambda df: df["prob_crossover"] * df["crossover_detection_prob"])
        ["final_prob"].mean()
    )

    n = mapped_read_numbers[sample_id]
    print(sample_id, (fake_reads_df["accessible_ratio"] > 0.5).mean(), p, n)
# Out:
# PD46180c 0.8791998181404864 9.503485492640713e-05 5819160
# PD50477f 0.8804837023230441 6.42808304041162e-05 5671375
# PD50489e 0.8779434494044913 3.0360603199559536e-05 6064631
# PD50508b 0.8806709700881898 0.00010362266818517417 3947252
# PD50508f 0.879154353262105 0.00010600139666005053 2778593
# PD50519d 0.8841258296208746 5.3591670671569125e-05 4971177
# PD50521b 0.8826310286831219 0.00010518758910807553 6293834
# PD50521e 0.8786363636363637 7.213676486640542e-05 6125876
# PD50523b 0.8834386507250989 7.439390067293335e-05 4740213
